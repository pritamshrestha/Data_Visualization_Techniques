# %%
# importing datasets
data<-read.csv("ppg2008.csv")
head(data)
# Out:
#   Name           G  MIN  PTS  FGM  FGA  FGP   FTM FTA FTP   ... X3PA X3PP  ORB
# 1 Dwyane Wade    79 38.6 30.2 10.8 22.0 0.491 7.5 9.8 0.765 ... 3.5  0.317 1.1
# 2 LeBron James   81 37.7 28.4  9.7 19.9 0.489 7.3 9.4 0.780 ... 4.7  0.344 1.3
# 3 Kobe Bryant    82 36.2 26.8  9.8 20.9 0.467 5.9 6.9 0.856 ... 4.1  0.351 1.1
# 4 Dirk Nowitzki  81 37.7 25.9  9.6 20.0 0.479 6.0 6.7 0.890 ... 2.1  0.359 1.1
# 5 Danny Granger  67 36.2 25.8  8.5 19.1 0.447 6.0 6.9 0.878 ... 6.7  0.404 0.7
# 6 Kevin Durant   74 39.0 25.3  8.9 18.8 0.476 6.1 7.1 0.863 ... 3.1  0.422 1.0
#   DRB TRB AST STL BLK TO  PF
# 1 3.9 5.0 7.5 2.2 1.3 3.4 2.3
# 2 6.3 7.6 7.2 1.7 1.1 3.0 1.7
# 3 4.1 5.2 4.9 1.5 0.5 2.6 2.3
# 4 7.3 8.4 2.4 0.8 0.8 1.9 2.2
# 5 4.4 5.1 2.7 1.0 1.4 2.5 3.1
# 6 5.5 6.5 2.8 1.3 0.7 3.0 1.8

# %%
# importing another datasets
data1<-read.csv("costcos-geocoded.csv")
head(data1)
# Out:
#   Address                   City       State   Zip.Code   Latitude Longitude
# 1 1205 N. Memorial Parkway  Huntsville Alabama 35801-5930 34.74309  -86.60096
# 2 3650 Galleria Circle      Hoover     Alabama 35244-2346 33.37765  -86.81242
# 3 8251 Eastchase Parkway    Montgomery Alabama 36117      32.36389  -86.15088
# 4 5225 Commercial Boulevard Juneau     Alaska  99801-7210 58.35920 -134.48300
# 5 330 West Dimond Blvd      Anchorage  Alaska  99515-1950 61.14327 -149.88422
# 6 4125 DeBarr Road          Anchorage  Alaska  99508-3115 61.21081 -149.80434

# %%
# creating heatmap
data_matrix<-data.matrix(data)# creating data matrix
data_heatmap <- heatmap(data_matrix, Rowv=NA, Colv=NA, col = heat.colors(24), scale="column", margins=c(5,10),main="Heatmap using R")
# Out:
# Plot with title "Heatmap using R"

# %%
# Reference:http://eriqande.github.io/rep-res-web/lectures/making-maps-with-R.html

library(ggplot2)
#library(ggmap)
library(maps)
library(mapdata)
# displaying usa maps
usa <- map_data("usa")
# simplemap
gg1 <- ggplot() + 
  geom_polygon(data = usa_map, aes(x=long, y = lat, group = group), fill = "red", color = "blue") + 
  coord_fixed(1.3)
gg1+
geom_point(data = data1, aes(x = Longitude, y = Latitude), color = "green") +ggtitle("Locations of costco in USA")
# Out:
# plot without title

# %%
# contour Map
ggplot(data, aes(x=G, y=FTA))+
  theme_bw()+
  geom_point(alpha=0.1, col='green')+
  geom_density2d(color='red')+
  ggtitle('Contour Plot')+
  labs(x='FTM', y='FTA')
# Out:
# plot without title

# %%
# Thanks !!!
